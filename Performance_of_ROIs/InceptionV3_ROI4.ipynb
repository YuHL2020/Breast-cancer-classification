# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from keras.applications import ResNet50,MobileNet,InceptionV3
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Model, Sequential
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
import tensorflow as tf


# %matplotlib inline
# Out:
# Using TensorFlow backend.
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

benign_train = np.array(Dataset_loader('C:/Users/user/Desktop/github/train/benign',224))
malign_train = np.array(Dataset_loader('C:/Users/user/Desktop/github/train/mallignant',224))
benign_test = np.array(Dataset_loader('C:/Users/user/Desktop/github/validation/benign',224))
malign_test = np.array(Dataset_loader('C:/Users/user/Desktop/github/validation/mallignant',224))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 267/267 [00:01<00:00, 159.73it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 92/92 [00:00<00:00, 153.85it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 89/89 [00:00<00:00, 165.41it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 31/31 [00:00<00:00, 153.24it/s]

# %%
# Skin Cancer: Malignant vs. Benign
# Create labels
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# Merge data 
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# To categorical
Y_train1 = to_categorical(Y_train, num_classes= 2)
Y_test1 = to_categorical(Y_test, num_classes= 2)

# %%
X_train.shape
# Out:
# (359, 224, 224, 3)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train1, 
    test_size=0.2, 
    random_state=11
)

# %%
# # Display first 15 images of moles, and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Mallignant')
    plt.imshow(x_train[i], interpolation='nearest')
plt.show()

# %%
BATCH_SIZE = 16

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True,  # randomly flip images
    )

# %%
def build_model(backbone, lr=1e-4):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(2, activation='softmax'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['accuracy']
    )
    
    return model

# %%
K.clear_session()
gc.collect()

resnet = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)


 


model = build_model(resnet ,lr = 1e-4)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\keras\backend\tensorflow_backend.py:1290: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Model)         (None, 5, 5, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 2048)              8192
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 4098
# =================================================================
# Total params: 21,815,074
# Trainable params: 21,776,546
# Non-trainable params: 38,528
# _________________________________________________________________

# %%
# Learning Rate Reducer
learn_control = ReduceLROnPlateau(monitor='val_acc', patience=10,
                                  verbose=1,factor=0.2, min_lr=1e-7)

# Checkpoint
filepath="huaxi_Inception_zhongliu_weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=100,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# Epoch 1/100
# 17/17 [===========================>..] - ETA: 3s - loss: 0.9705 - acc: 0.5221Epoch 00000: val_acc improved from -inf to 0.69444, saving model to huaxi_Inception_zhongliu_weights.best.hdf5
# 18/17 [==============================] - 69s - loss: 0.9807 - acc: 0.5227 - val_loss: 0.6297 - val_acc: 0.6944
# Epoch 2/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.9627 - acc: 0.5441Epoch 00001: val_acc improved from 0.69444 to 0.77778, saving model to huaxi_Inception_zhongliu_weights.best.hdf5
# 18/17 [==============================] - 14s - loss: 0.9543 - acc: 0.5435 - val_loss: 0.5417 - val_acc: 0.7778
# Epoch 3/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.8663 - acc: 0.6397Epoch 00002: val_acc improved from 0.77778 to 0.81944, saving model to huaxi_Inception_zhongliu_weights.best.hdf5
# 18/17 [==============================] - 15s - loss: 0.8625 - acc: 0.6338 - val_loss: 0.4469 - val_acc: 0.8194
# Epoch 4/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.9014 - acc: 0.5882Epoch 00003: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.9165 - acc: 0.5852 - val_loss: 0.4196 - val_acc: 0.7917
# Epoch 5/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.9072 - acc: 0.6066Epoch 00004: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.9232 - acc: 0.6026 - val_loss: 0.4110 - val_acc: 0.8194
# Epoch 6/100
# 17/17 [===========================>..] - ETA: 0s - loss: 1.0146 - acc: 0.6029Epoch 00005: val_acc improved from 0.81944 to 0.86111, saving model to huaxi_Inception_zhongliu_weights.best.hdf5
# 18/17 [==============================] - 15s - loss: 1.0160 - acc: 0.5991 - val_loss: 0.3934 - val_acc: 0.8611
# Epoch 7/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.8498 - acc: 0.6140Epoch 00006: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.8380 - acc: 0.6169 - val_loss: 0.4842 - val_acc: 0.8472
# Epoch 8/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7118 - acc: 0.6765Epoch 00007: val_acc did not improve
# 18/17 [==============================] - 10s - loss: 0.7361 - acc: 0.6685 - val_loss: 0.8499 - val_acc: 0.6389
# Epoch 9/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.9240 - acc: 0.6324Epoch 00008: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.9430 - acc: 0.6269 - val_loss: 0.5792 - val_acc: 0.7361
# Epoch 10/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.8243 - acc: 0.6765Epoch 00009: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.8435 - acc: 0.6722 - val_loss: 0.6041 - val_acc: 0.6944
# Epoch 11/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7905 - acc: 0.6691Epoch 00010: val_acc did not improve
# 18/17 [==============================] - 11s - loss: 0.7772 - acc: 0.6764 - val_loss: 0.7488 - val_acc: 0.7083
# Epoch 12/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.8475 - acc: 0.6507Epoch 00011: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.8622 - acc: 0.6516 - val_loss: 0.9121 - val_acc: 0.6528
# Epoch 13/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7817 - acc: 0.6801Epoch 00012: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.7672 - acc: 0.6831 - val_loss: 0.5532 - val_acc: 0.7639
# Epoch 14/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7021 - acc: 0.7132Epoch 00013: val_acc improved from 0.86111 to 0.87500, saving model to huaxi_Inception_zhongliu_weights.best.hdf5
# 18/17 [==============================] - 16s - loss: 0.7525 - acc: 0.7070 - val_loss: 0.5000 - val_acc: 0.8750
# Epoch 15/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7860 - acc: 0.7059Epoch 00014: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.7740 - acc: 0.7037 - val_loss: 0.5061 - val_acc: 0.8333
# Epoch 16/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6871 - acc: 0.7353Epoch 00015: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.7069 - acc: 0.7241 - val_loss: 0.4462 - val_acc: 0.8333
# Epoch 17/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7402 - acc: 0.7426Epoch 00016: val_acc did not improve
# 18/17 [==============================] - 12s - loss: 0.7410 - acc: 0.7384 - val_loss: 0.7765 - val_acc: 0.5972
# Epoch 18/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.8793 - acc: 0.6654Epoch 00017: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.8684 - acc: 0.6692 - val_loss: 0.6619 - val_acc: 0.7361
# Epoch 19/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7128 - acc: 0.7022Epoch 00018: val_acc did not improve
# 18/17 [==============================] - 11s - loss: 0.7052 - acc: 0.7113 - val_loss: 0.4710 - val_acc: 0.8194
# Epoch 20/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6137 - acc: 0.7169Epoch 00019: val_acc did not improve
# 18/17 [==============================] - 12s - loss: 0.5997 - acc: 0.7252 - val_loss: 0.5159 - val_acc: 0.8056
# Epoch 21/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6529 - acc: 0.7279Epoch 00020: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6770 - acc: 0.7172 - val_loss: 0.7964 - val_acc: 0.7083
# Epoch 22/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6925 - acc: 0.7279Epoch 00021: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.7015 - acc: 0.7245 - val_loss: 0.8992 - val_acc: 0.7500
# Epoch 23/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6365 - acc: 0.7316Epoch 00022: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.6525 - acc: 0.7354 - val_loss: 0.7023 - val_acc: 0.8333
# Epoch 24/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7108 - acc: 0.7096Epoch 00023: val_acc did not improve
# 18/17 [==============================] - 9s - loss: 0.7124 - acc: 0.7109 - val_loss: 2.3172 - val_acc: 0.6806
# Epoch 25/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5740 - acc: 0.7610
# Epoch 00024: reducing learning rate to 1.9999999494757503e-05.
# Epoch 00024: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.5735 - acc: 0.7595 - val_loss: 1.0381 - val_acc: 0.7361
# Epoch 26/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6339 - acc: 0.7463Epoch 00025: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6542 - acc: 0.7271 - val_loss: 1.1431 - val_acc: 0.7778
# Epoch 27/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6835 - acc: 0.7243Epoch 00026: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6857 - acc: 0.7285 - val_loss: 0.6183 - val_acc: 0.7778
# Epoch 28/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6188 - acc: 0.7794Epoch 00027: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6104 - acc: 0.7806 - val_loss: 0.5346 - val_acc: 0.8333
# Epoch 29/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5862 - acc: 0.7574Epoch 00028: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6118 - acc: 0.7486 - val_loss: 0.5219 - val_acc: 0.8194
# Epoch 30/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7291 - acc: 0.7022Epoch 00029: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.7295 - acc: 0.7039 - val_loss: 0.6301 - val_acc: 0.8056
# Epoch 31/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6835 - acc: 0.7243Epoch 00030: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6779 - acc: 0.7322 - val_loss: 0.6674 - val_acc: 0.8056
# Epoch 32/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6241 - acc: 0.7574Epoch 00031: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6373 - acc: 0.7523 - val_loss: 0.5824 - val_acc: 0.8333
# Epoch 33/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6360 - acc: 0.7206Epoch 00032: val_acc did not improve
# 18/17 [==============================] - 11s - loss: 0.6171 - acc: 0.7287 - val_loss: 0.5561 - val_acc: 0.8333
# Epoch 34/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7281 - acc: 0.7500Epoch 00033: val_acc did not improve
# 18/17 [==============================] - 10s - loss: 0.7212 - acc: 0.7528 - val_loss: 0.6367 - val_acc: 0.7917
# Epoch 35/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6423 - acc: 0.7059
# Epoch 00034: reducing learning rate to 3.999999898951501e-06.
# Epoch 00034: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.6424 - acc: 0.7074 - val_loss: 0.6298 - val_acc: 0.8056
# Epoch 36/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7062 - acc: 0.7096Epoch 00035: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6996 - acc: 0.7109 - val_loss: 0.6448 - val_acc: 0.8194
# Epoch 37/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6148 - acc: 0.7757Epoch 00036: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.5982 - acc: 0.7808 - val_loss: 0.6213 - val_acc: 0.8194
# Epoch 38/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6101 - acc: 0.7647Epoch 00037: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6129 - acc: 0.7593 - val_loss: 0.6067 - val_acc: 0.8333
# Epoch 39/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6379 - acc: 0.7022Epoch 00038: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6231 - acc: 0.7076 - val_loss: 0.6029 - val_acc: 0.8333
# Epoch 40/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5892 - acc: 0.7537Epoch 00039: val_acc did not improve
# 18/17 [==============================] - 8s - loss: 0.5904 - acc: 0.7452 - val_loss: 0.5852 - val_acc: 0.8333
# Epoch 41/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7362 - acc: 0.7169Epoch 00040: val_acc did not improve
# 18/17 [==============================] - 11s - loss: 0.7279 - acc: 0.7104 - val_loss: 0.5499 - val_acc: 0.8472
# Epoch 42/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6579 - acc: 0.7169Epoch 00041: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6499 - acc: 0.7104 - val_loss: 0.5129 - val_acc: 0.8472
# Epoch 43/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6036 - acc: 0.7243Epoch 00042: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6202 - acc: 0.7174 - val_loss: 0.5089 - val_acc: 0.8472
# Epoch 44/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5994 - acc: 0.7647Epoch 00043: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6093 - acc: 0.7519 - val_loss: 0.4952 - val_acc: 0.8472
# Epoch 45/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6803 - acc: 0.7500
# Epoch 00044: reducing learning rate to 7.999999979801942e-07.
# Epoch 00044: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6742 - acc: 0.7417 - val_loss: 0.4885 - val_acc: 0.8472
# Epoch 46/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6159 - acc: 0.7574Epoch 00045: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6017 - acc: 0.7634 - val_loss: 0.5047 - val_acc: 0.8472
# Epoch 47/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6056 - acc: 0.7574Epoch 00046: val_acc did not improve
# 18/17 [==============================] - 10s - loss: 0.6159 - acc: 0.7486 - val_loss: 0.4962 - val_acc: 0.8472
# Epoch 48/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6553 - acc: 0.7426Epoch 00047: val_acc did not improve
# 18/17 [==============================] - 12s - loss: 0.6736 - acc: 0.7384 - val_loss: 0.4931 - val_acc: 0.8472
# Epoch 49/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5940 - acc: 0.7610Epoch 00048: val_acc did not improve
# 18/17 [==============================] - 11s - loss: 0.5828 - acc: 0.7632 - val_loss: 0.5045 - val_acc: 0.8333
# Epoch 50/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6153 - acc: 0.7463Epoch 00049: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6132 - acc: 0.7456 - val_loss: 0.5016 - val_acc: 0.8333
# Epoch 51/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6211 - acc: 0.7243Epoch 00050: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6474 - acc: 0.7211 - val_loss: 0.4925 - val_acc: 0.8333
# Epoch 52/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7042 - acc: 0.7500Epoch 00051: val_acc did not improve
# 18/17 [==============================] - 16s - loss: 0.6808 - acc: 0.7565 - val_loss: 0.4878 - val_acc: 0.8333
# Epoch 53/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5748 - acc: 0.7610Epoch 00052: val_acc did not improve
# 18/17 [==============================] - 8s - loss: 0.5741 - acc: 0.7595 - val_loss: 0.4786 - val_acc: 0.8333
# Epoch 54/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6231 - acc: 0.7500Epoch 00053: val_acc did not improve
# 18/17 [==============================] - 12s - loss: 0.6309 - acc: 0.7417 - val_loss: 0.4718 - val_acc: 0.8611
# Epoch 55/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6540 - acc: 0.7243
# Epoch 00054: reducing learning rate to 1.600000018697756e-07.
# Epoch 00054: val_acc did not improve
# 18/17 [==============================] - 16s - loss: 0.6491 - acc: 0.7248 - val_loss: 0.4756 - val_acc: 0.8472
# Epoch 56/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7982 - acc: 0.6654Epoch 00055: val_acc did not improve
# 18/17 [==============================] - 16s - loss: 0.7817 - acc: 0.6729 - val_loss: 0.4629 - val_acc: 0.8611
# Epoch 57/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5662 - acc: 0.7574Epoch 00056: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.5643 - acc: 0.7560 - val_loss: 0.4712 - val_acc: 0.8472
# Epoch 58/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5428 - acc: 0.7537Epoch 00057: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.5712 - acc: 0.7489 - val_loss: 0.4797 - val_acc: 0.8333
# Epoch 59/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5685 - acc: 0.7610Epoch 00058: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.5674 - acc: 0.7521 - val_loss: 0.4726 - val_acc: 0.8472
# Epoch 60/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6048 - acc: 0.7500Epoch 00059: val_acc did not improve
# 18/17 [==============================] - 9s - loss: 0.6083 - acc: 0.7565 - val_loss: 0.4788 - val_acc: 0.8333
# Epoch 61/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5450 - acc: 0.7684Epoch 00060: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.5524 - acc: 0.7627 - val_loss: 0.4813 - val_acc: 0.8333
# Epoch 62/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6429 - acc: 0.7059Epoch 00061: val_acc did not improve
# 18/17 [==============================] - 10s - loss: 0.6401 - acc: 0.7074 - val_loss: 0.4835 - val_acc: 0.8333
# Epoch 63/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6637 - acc: 0.7279Epoch 00062: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6573 - acc: 0.7282 - val_loss: 0.4713 - val_acc: 0.8472
# Epoch 64/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6339 - acc: 0.7132Epoch 00063: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6195 - acc: 0.7180 - val_loss: 0.4701 - val_acc: 0.8472
# Epoch 65/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6485 - acc: 0.7757
# Epoch 00064: reducing learning rate to 1e-07.
# Epoch 00064: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6425 - acc: 0.7771 - val_loss: 0.4738 - val_acc: 0.8472
# Epoch 66/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6806 - acc: 0.7206Epoch 00065: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6703 - acc: 0.7250 - val_loss: 0.4735 - val_acc: 0.8472
# Epoch 67/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5816 - acc: 0.7426Epoch 00066: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.5926 - acc: 0.7347 - val_loss: 0.4715 - val_acc: 0.8472
# Epoch 68/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6520 - acc: 0.7463Epoch 00067: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6493 - acc: 0.7456 - val_loss: 0.4735 - val_acc: 0.8472
# Epoch 69/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6625 - acc: 0.7169Epoch 00068: val_acc did not improve
# 18/17 [==============================] - 11s - loss: 0.6484 - acc: 0.7252 - val_loss: 0.4739 - val_acc: 0.8611
# Epoch 70/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6157 - acc: 0.7463Epoch 00069: val_acc did not improve
# 18/17 [==============================] - 12s - loss: 0.6197 - acc: 0.7493 - val_loss: 0.4768 - val_acc: 0.8472
# Epoch 71/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6722 - acc: 0.7059Epoch 00070: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.6660 - acc: 0.7074 - val_loss: 0.4815 - val_acc: 0.8333
# Epoch 72/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6245 - acc: 0.7390Epoch 00071: val_acc did not improve
# 18/17 [==============================] - 11s - loss: 0.6232 - acc: 0.7387 - val_loss: 0.4748 - val_acc: 0.8472
# Epoch 73/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6523 - acc: 0.7353Epoch 00072: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6494 - acc: 0.7315 - val_loss: 0.4706 - val_acc: 0.8472
# Epoch 74/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5696 - acc: 0.7721Epoch 00073: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.5709 - acc: 0.7699 - val_loss: 0.4821 - val_acc: 0.8472
# Epoch 75/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5968 - acc: 0.7390Epoch 00074: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.5787 - acc: 0.7497 - val_loss: 0.4828 - val_acc: 0.8611
# Epoch 76/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6191 - acc: 0.7316Epoch 00075: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6049 - acc: 0.7391 - val_loss: 0.4791 - val_acc: 0.8472
# Epoch 77/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6084 - acc: 0.7463Epoch 00076: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6219 - acc: 0.7493 - val_loss: 0.4788 - val_acc: 0.8472
# Epoch 78/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6916 - acc: 0.7316Epoch 00077: val_acc did not improve
# 18/17 [==============================] - 16s - loss: 0.7228 - acc: 0.7206 - val_loss: 0.4849 - val_acc: 0.8333
# Epoch 79/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6564 - acc: 0.7316Epoch 00078: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6484 - acc: 0.7317 - val_loss: 0.4839 - val_acc: 0.8333
# Epoch 80/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6383 - acc: 0.7243Epoch 00079: val_acc did not improve
# 18/17 [==============================] - 8s - loss: 0.6261 - acc: 0.7285 - val_loss: 0.4871 - val_acc: 0.8333
# Epoch 81/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6712 - acc: 0.7279Epoch 00080: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.6661 - acc: 0.7319 - val_loss: 0.4889 - val_acc: 0.8333
# Epoch 82/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5992 - acc: 0.7500Epoch 00081: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.5833 - acc: 0.7528 - val_loss: 0.4949 - val_acc: 0.8333
# Epoch 83/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6704 - acc: 0.7500Epoch 00082: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6743 - acc: 0.7491 - val_loss: 0.5046 - val_acc: 0.8333
# Epoch 84/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6511 - acc: 0.7426Epoch 00083: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.6458 - acc: 0.7421 - val_loss: 0.5064 - val_acc: 0.8333
# Epoch 85/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5380 - acc: 0.7684Epoch 00084: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.5467 - acc: 0.7664 - val_loss: 0.4898 - val_acc: 0.8472
# Epoch 86/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5799 - acc: 0.7684Epoch 00085: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.5698 - acc: 0.7701 - val_loss: 0.4912 - val_acc: 0.8472
# Epoch 87/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5793 - acc: 0.7463Epoch 00086: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.6022 - acc: 0.7419 - val_loss: 0.4949 - val_acc: 0.8333
# Epoch 88/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5530 - acc: 0.7721Epoch 00087: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.5553 - acc: 0.7699 - val_loss: 0.4940 - val_acc: 0.8333
# Epoch 89/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6138 - acc: 0.7500Epoch 00088: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6111 - acc: 0.7528 - val_loss: 0.4855 - val_acc: 0.8333
# Epoch 90/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6441 - acc: 0.7537Epoch 00089: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6463 - acc: 0.7562 - val_loss: 0.4831 - val_acc: 0.8333
# Epoch 91/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6525 - acc: 0.6949Epoch 00090: val_acc did not improve
# 18/17 [==============================] - 11s - loss: 0.6397 - acc: 0.7007 - val_loss: 0.4798 - val_acc: 0.8333
# Epoch 92/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6475 - acc: 0.7279Epoch 00091: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6309 - acc: 0.7319 - val_loss: 0.4751 - val_acc: 0.8472
# Epoch 93/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6468 - acc: 0.7537Epoch 00092: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6509 - acc: 0.7489 - val_loss: 0.4777 - val_acc: 0.8472
# Epoch 94/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6614 - acc: 0.7243Epoch 00093: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.6706 - acc: 0.7285 - val_loss: 0.4822 - val_acc: 0.8472
# Epoch 95/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6653 - acc: 0.7463Epoch 00094: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.6591 - acc: 0.7493 - val_loss: 0.4815 - val_acc: 0.8472
# Epoch 96/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5781 - acc: 0.7574Epoch 00095: val_acc did not improve
# 18/17 [==============================] - 15s - loss: 0.5841 - acc: 0.7449 - val_loss: 0.4829 - val_acc: 0.8333
# Epoch 97/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6498 - acc: 0.7537Epoch 00096: val_acc did not improve
# 18/17 [==============================] - 16s - loss: 0.6402 - acc: 0.7525 - val_loss: 0.4725 - val_acc: 0.8472
# Epoch 98/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7100 - acc: 0.7537Epoch 00097: val_acc did not improve
# 18/17 [==============================] - 12s - loss: 0.7100 - acc: 0.7562 - val_loss: 0.4831 - val_acc: 0.8333
# Epoch 99/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5735 - acc: 0.7463Epoch 00098: val_acc did not improve
# 18/17 [==============================] - 13s - loss: 0.5853 - acc: 0.7419 - val_loss: 0.4832 - val_acc: 0.8333
# Epoch 100/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5529 - acc: 0.7684Epoch 00099: val_acc did not improve
# 18/17 [==============================] - 14s - loss: 0.5721 - acc: 0.7591 - val_loss: 0.4872 - val_acc: 0.8333

# %%
with open('history.json', 'w') as f:
    json.dump(str(history.history), f)

# %%
history_df = pd.DataFrame(history.history)
history_df[['acc', 'val_acc']].plot()
# Out:
# <AxesSubplot:>

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
model.load_weights("huaxi_Inception_zhongliu_weights.best.hdf5")

# %%
Y_val_pred = model.predict(x_val)

# %%
from sklearn.metrics import classification_report
print(classification_report(np.argmax(y_val, axis=1),np.argmax(Y_val_pred, axis=1),target_names=['benign','mallignant']))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.93      0.92      0.92        59
#   mallignant       0.64      0.69      0.67        13
#
#     accuracy                           0.88        72
#    macro avg       0.79      0.80      0.79        72
# weighted avg       0.88      0.88      0.88        72

# %%
accuracy_score(np.argmax(y_val, axis=1), np.argmax(Y_val_pred, axis=1))
# Out:
# 0.875

# %%
Y_pred = model.predict(X_test)

# %%
tta_steps = 10
predictions = []

for i in tqdm(range(tta_steps)):
    preds = model.predict_generator(train_generator.flow(X_test, batch_size=BATCH_SIZE, shuffle=False),
                                    steps = len(X_test)/BATCH_SIZE)
    
    predictions.append(preds)
    gc.collect()
    
Y_pred_tta = np.mean(predictions, axis=0) # 计算每一列的均值
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:29<00:00,  2.99s/it]

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test1, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[73 16]
#  [13 18]]

# %%
cm = confusion_matrix(np.argmax(Y_test1, axis=1), np.argmax(Y_pred_tta, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[87  2]
#  [29  2]]

# %%
from sklearn.metrics import classification_report
#classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
print(classification_report(np.argmax(Y_test1, axis=1),np.argmax(Y_pred, axis=1),target_names=['benign','mallignant']))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.85      0.82      0.83        89
#   mallignant       0.53      0.58      0.55        31
#
#     accuracy                           0.76       120
#    macro avg       0.69      0.70      0.69       120
# weighted avg       0.77      0.76      0.76       120

# %%
from sklearn.metrics import classification_report
#classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
print(classification_report(np.argmax(Y_test1, axis=1),np.argmax(Y_pred_tta, axis=1),target_names=['benign','mallignant']))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.75      0.98      0.85        89
#   mallignant       0.50      0.06      0.11        31
#
#     accuracy                           0.74       120
#    macro avg       0.62      0.52      0.48       120
# weighted avg       0.69      0.74      0.66       120

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(Y_test1)):
    if(np.argmax(Y_test1[i])==np.argmax(Y_pred_tta[i])):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(Y_test1)):
    if(not np.argmax(Y_test1[i])==np.argmax(Y_pred_tta[i])):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# # Display first 8 images of benign
w=60
h=40
fig=plt.figure(figsize=(18, 10))
columns = 4
rows = 2

def Transfername(namecode):
    if namecode==0:
        return "Benign"
    else:
        return "Malignant"
    
for i in range(len(prop_class)):
    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title("Predicted result:"+ Transfername(np.argmax(Y_pred_tta[prop_class[i]]))
                       +"\n"+"Actual result: "+ Transfername(np.argmax(Y_test[prop_class[i]])))
    plt.imshow(X_test[prop_class[i]], interpolation='nearest')
plt.show()

# %%
layer_name = 'batch_normalization_95'
FC_layer_model = Model(inputs=model.input,
                                 outputs=model.get_layer(layer_name).output)

# %%
import glob
import cv2
import os
#Find the Features for n number of train images and we will get n x 2048
#This means we will get 2048 features for each images.

patth =  'C:/Users/user/Desktop/github/train'


j=0
features=np.zeros(shape=(X_train.shape[0],2048))
folders = list(filter(lambda x: os.path.isdir(os.path.join(patth, x)), os.listdir(patth)))
for i in folders:
  img_patth = os.path.join(patth,i)
  for img_path in glob.glob(img_patth + '/*.png'):
    img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
    img = cv2.resize(img, (224, 224))
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    img = np.expand_dims(img,axis=0)
    FC_output = FC_layer_model.predict(img)
    features[j]=FC_output
    j+=1

# %%
features.shape
# Out:
# (359, 2048)

# %%
np.save('features', features)

# %%
#Name the feature rows as f_0, f_1, f_2...
feature_col=[]
for i in range(2048):
    feature_col.append("f_"+str(i))
    i+=1

# %%
#Create DataFrame with features and coloumn name

import pandas as pd 
train_features=pd.DataFrame(data=features,columns=feature_col)
feature_col = np.array(feature_col)

train_class = list(np.unique(Y_train))
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', Y_train.shape)
# Out:
# Training Features Shape: (359, 2048)
# Training Labels Shape: (359,)

# %%
train_features
# Out:
#           f_0       f_1       f_2       f_3       f_4       f_5       f_6  \
# 0    0.287206 -0.104349 -0.145898  0.555416  0.084140 -0.416026 -0.358017
# 1    0.986210 -0.241931  0.137955  0.548721  0.369139  0.244109 -0.462151
# 2    0.371583  0.660963  0.055519  0.780070 -0.154124  0.178652  0.458310
# 3   -0.076457 -0.002505  0.290164  0.568645 -0.295628 -0.175397 -0.227031
# 4    0.026534 -0.004721 -0.185964 -0.194032 -0.089036 -0.052142 -0.230869
# ..        ...       ...       ...       ...       ...       ...       ...
# 354  1.079080 -0.405332 -0.237337 -0.174538 -0.344863 -0.453618 -0.182609
# 355  0.279681 -0.333932 -0.170926  0.064364 -0.318703  0.330467  0.096174
# 356 -0.093898 -0.347526 -0.203967 -0.361374 -0.378325 -0.451054 -0.503837
# 357 -0.349618  0.112730  0.369989 -0.114383 -0.225679 -0.301123 -0.337997
# 358  0.867441 -0.281573  0.625116  0.100159 -0.477064 -0.063788 -0.404621
#
#           f_7       f_8       f_9  ...    f_2038    f_2039    f_2040  \
# 0    0.795768  0.287916 -0.182569  ... -0.488482  0.028105 -0.441052
# 1    0.306358  0.925939  0.082349  ... -0.395655 -0.301445 -0.532059
# 2    0.448721 -0.256500 -0.306336  ... -0.488482  0.919536 -0.406625
# 3   -0.130427 -0.243849 -0.326407  ... -0.476549  0.068782 -0.024331
# 4   -0.145692 -0.012902 -0.292425  ... -0.486010  0.393936 -0.471552
# ..        ...       ...       ...  ...       ...       ...       ...
# 354 -0.060574  0.240945  1.037658  ... -0.488482  1.283630 -0.243927
# 355 -0.170608 -0.134713 -0.238318  ... -0.488482 -0.123505 -0.482078
# 356  0.027328 -0.232331  2.269762  ...  0.713774 -0.461551  0.125713
# 357 -0.177407 -0.245992 -0.129360  ... -0.479152 -0.399250 -0.276949
# 358  0.548165 -0.498360  0.073573  ...  0.308017  0.553312 -0.462315
#
#        f_2041    f_2042    f_2043    f_2044    f_2045    f_2046    f_2047
# 0    0.202337 -0.472556 -0.397992 -0.505117 -0.472146 -0.471732 -0.431921
# 1    1.247489  2.256810 -0.025355  0.285397 -0.246932  0.130252  2.100276
# 2    2.983991 -0.208559 -0.277932 -0.316219 -0.318694 -0.410456  0.071214
# 3    1.490001 -0.324186 -0.410173 -0.134058  0.832640  0.566666  1.113162
# 4    0.859634 -0.453084 -0.347497 -0.356018 -0.349648 -0.322691 -0.328931
# ..        ...       ...       ...       ...       ...       ...       ...
# 354  0.914592  1.323014 -0.450774  1.245275  0.631090 -0.399122  2.284320
# 355  0.034027 -0.428990 -0.220119 -0.497054 -0.381345 -0.399345 -0.431921
# 356  1.238336  0.596570 -0.445740  0.146747  0.891500  1.977095  0.425378
# 357  0.321856 -0.455590  0.445814 -0.238545 -0.459203 -0.180472 -0.081377
# 358  2.966130  1.192561  0.662291 -0.496082  0.095548  0.343912  2.539381
#
# [359 rows x 2048 columns]

# %%
np.savetxt("zhongliu.csv", train_features, delimiter=',')

# %%
import glob
import cv2
import os
#Find the Features for n number of train images and we will get n x 2048
#This means we will get 2048 features for each images.

patth =  'C:/Users/user/Desktop/github/validation'

k=0
features_test=np.zeros(shape=(Y_test.shape[0],2048))
folders = list(filter(lambda x: os.path.isdir(os.path.join(patth, x)), os.listdir(patth)))
for i in folders:
  img_patth = os.path.join(patth,i)
  for img_path in glob.glob(img_patth + '/*.png'):
    img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
    img = cv2.resize(img, (224, 224))
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    img = np.expand_dims(img,axis=0)
    FC_output = FC_layer_model.predict(img)
    features_test[k]=FC_output
    k+=1

# %%
np.save('features_test',features_test)

# %%
#Create DataFrame with features and coloumn name
import pandas as pd
test_features=pd.DataFrame(data=features_test,columns=feature_col)
feature_col = np.array(feature_col)

print('Test Features Shape:', test_features.shape)
print('Test Labels Shape:', Y_test.shape)
# Out:
# Test Features Shape: (120, 2048)
# Test Labels Shape: (120,)

# %%
test_features
# Out:
#           f_0       f_1       f_2       f_3       f_4       f_5       f_6  \
# 0   -0.102143 -0.356671  0.208797  0.141474 -0.419289 -0.405512  0.005849
# 1    0.417004 -0.028008 -0.092067  0.263791  0.209693 -0.225607  0.054421
# 2    0.002683 -0.321386  0.496419  0.034955 -0.293261 -0.315797 -0.244978
# 3    0.164024 -0.072879 -0.123634  0.164652 -0.360041 -0.197810 -0.261209
# 4   -0.158691  0.031335  0.005426  0.286328  0.175299 -0.006147 -0.138277
# ..        ...       ...       ...       ...       ...       ...       ...
# 115 -0.088563  0.446355 -0.098238  1.053149 -0.464538 -0.016254 -0.317745
# 116  1.096952 -0.348388  0.568423 -0.038382 -0.405847 -0.413507 -0.340423
# 117 -0.052442 -0.118526  0.447890  0.227983 -0.192219 -0.312465 -0.382257
# 118 -0.091464 -0.199461 -0.231531 -0.426909 -0.148315 -0.403129  0.159345
# 119  0.048831 -0.121339  0.912515  0.222787 -0.468677 -0.540691 -0.514706
#
#           f_7       f_8       f_9  ...    f_2038    f_2039    f_2040  \
# 0   -0.093051 -0.313567 -0.354868  ... -0.488482 -0.454018 -0.475290
# 1    0.392200  0.603252 -0.453006  ... -0.488482  0.055670 -0.523781
# 2    0.723045  0.062280 -0.426263  ... -0.408532 -0.394374 -0.450677
# 3   -0.347696  0.085242 -0.463836  ... -0.444583  0.262180 -0.434296
# 4    0.294744 -0.077044 -0.401070  ... -0.278110 -0.049256 -0.153545
# ..        ...       ...       ...  ...       ...       ...       ...
# 115  0.171447 -0.493479 -0.452009  ... -0.122295 -0.380552 -0.273495
# 116  0.007929 -0.300600  0.647961  ... -0.236877 -0.471587 -0.393366
# 117 -0.081950  0.178309  0.117917  ... -0.131661  0.588501 -0.512122
# 118 -0.006220  0.101158 -0.497006  ... -0.488482  0.555770 -0.457186
# 119  1.451713  0.105446  1.771515  ... -0.441524 -0.144862 -0.289715
#
#        f_2041    f_2042    f_2043    f_2044    f_2045    f_2046    f_2047
# 0   -0.398157 -0.435806 -0.246940  0.093755 -0.468024 -0.031052 -0.142082
# 1    2.129050 -0.248181 -0.437452 -0.521993 -0.486321 -0.471732 -0.423310
# 2   -0.444164 -0.477827 -0.466694  0.013558 -0.474666 -0.407392 -0.408442
# 3    1.167808 -0.331549 -0.295029 -0.003908 -0.422176 -0.400707 -0.402758
# 4    0.349326 -0.473933 -0.268920 -0.387719 -0.229347 -0.465742 -0.357288
# ..        ...       ...       ...       ...       ...       ...       ...
# 115  1.605114  0.342346 -0.259866 -0.456293  0.593302  0.048773  0.814269
# 116  0.040646 -0.312889 -0.459063 -0.386680 -0.134840  0.195767  1.481708
# 117  0.676616  0.060739 -0.309279 -0.228482 -0.029770  0.306086  1.338670
# 118 -0.309517 -0.477827 -0.466694 -0.233462 -0.506157 -0.454414 -0.180213
# 119  2.041646 -0.338227 -0.241725  0.780653 -0.456442  0.613187  1.619980
#
# [120 rows x 2048 columns]

# %%
np.savetxt("zhongliu_test.csv", test_features, delimiter=',')
