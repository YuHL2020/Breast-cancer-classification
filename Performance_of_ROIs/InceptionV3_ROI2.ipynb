# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from keras.applications import ResNet50,MobileNet,InceptionV3
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Model, Sequential
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
import tensorflow as tf


# %matplotlib inline
# Out:
# Using TensorFlow backend.
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

benign_train = np.array(Dataset_loader('C:/Users/user/Desktop/github/train/benign',224))
malign_train = np.array(Dataset_loader('C:/Users/user/Desktop/github/train/mallignant',224))
benign_test = np.array(Dataset_loader('C:/Users/user/Desktop/github/validation/benign',224))
malign_test = np.array(Dataset_loader('C:/Users/user/Desktop/github/validation/mallignant',224))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 267/267 [00:01<00:00, 137.34it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 92/92 [00:00<00:00, 134.32it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 89/89 [00:00<00:00, 142.99it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 31/31 [00:00<00:00, 150.91it/s]

# %%
# Skin Cancer: Malignant vs. Benign
# Create labels
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# Merge data 
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# To categorical
Y_train1 = to_categorical(Y_train, num_classes= 2)
Y_test1 = to_categorical(Y_test, num_classes= 2)

# %%
X_train.shape
# Out:
# (359, 224, 224, 3)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train1, 
    test_size=0.2, 
    random_state=11
)

# %%
# # Display first 15 images of moles, and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Mallignant')
    plt.imshow(x_train[i], interpolation='nearest')
plt.show()

# %%
BATCH_SIZE = 16

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True,  # randomly flip images
    )

# %%
def build_model(backbone, lr=1e-4):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(2, activation='softmax'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['accuracy']
    )
    
    return model

# %%
K.clear_session()
gc.collect()

resnet = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)


 


model = build_model(resnet ,lr = 1e-4)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\user\AppData\Local\conda\conda\envs\tf1.4py3.6\lib\site-packages\keras\backend\tensorflow_backend.py:1290: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Model)         (None, 5, 5, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 2048)              8192
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 4098
# =================================================================
# Total params: 21,815,074
# Trainable params: 21,776,546
# Non-trainable params: 38,528
# _________________________________________________________________

# %%
# Learning Rate Reducer
learn_control = ReduceLROnPlateau(monitor='val_acc', patience=10,
                                  verbose=1,factor=0.2, min_lr=1e-7)

# Checkpoint
filepath="huaxi_Inception_bydai_weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=100,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# Epoch 1/100
# 17/17 [===========================>..] - ETA: 3s - loss: 1.0380 - acc: 0.5294Epoch 00000: val_acc improved from -inf to 0.81944, saving model to huaxi_Inception_bydai_weights.best.hdf5
# 18/17 [==============================] - 71s - loss: 1.0313 - acc: 0.5333 - val_loss: 0.4291 - val_acc: 0.8194
# Epoch 2/100
# 17/17 [===========================>..] - ETA: 1s - loss: 0.9151 - acc: 0.5551Epoch 00001: val_acc did not improve
# 18/17 [==============================] - 32s - loss: 0.9018 - acc: 0.5613 - val_loss: 0.5629 - val_acc: 0.8194
# Epoch 3/100
# 17/17 [===========================>..] - ETA: 1s - loss: 0.8058 - acc: 0.6434Epoch 00002: val_acc improved from 0.81944 to 0.84722, saving model to huaxi_Inception_bydai_weights.best.hdf5
# 18/17 [==============================] - 33s - loss: 0.8022 - acc: 0.6336 - val_loss: 0.4333 - val_acc: 0.8472
# Epoch 4/100
# 17/17 [===========================>..] - ETA: 1s - loss: 0.9620 - acc: 0.5809Epoch 00003: val_acc did not improve
# 18/17 [==============================] - 32s - loss: 0.9611 - acc: 0.5819 - val_loss: 0.3947 - val_acc: 0.8472
# Epoch 5/100
# 17/17 [===========================>..] - ETA: 1s - loss: 0.8086 - acc: 0.6324Epoch 00004: val_acc improved from 0.84722 to 0.86111, saving model to huaxi_Inception_bydai_weights.best.hdf5
# 18/17 [==============================] - 33s - loss: 0.7847 - acc: 0.6416 - val_loss: 0.3826 - val_acc: 0.8611
# Epoch 6/100
# 17/17 [===========================>..] - ETA: 1s - loss: 0.8687 - acc: 0.6397Epoch 00005: val_acc improved from 0.86111 to 0.86111, saving model to huaxi_Inception_bydai_weights.best.hdf5
# 18/17 [==============================] - 34s - loss: 0.8745 - acc: 0.6338 - val_loss: 0.4325 - val_acc: 0.8611
# Epoch 7/100
# 17/17 [===========================>..] - ETA: 1s - loss: 0.7882 - acc: 0.6618Epoch 00006: val_acc did not improve
# 18/17 [==============================] - 32s - loss: 0.8295 - acc: 0.6510 - val_loss: 0.8088 - val_acc: 0.6528
# Epoch 8/100
# 17/17 [===========================>..] - ETA: 1s - loss: 0.8626 - acc: 0.6176Epoch 00007: val_acc did not improve
# 18/17 [==============================] - 24s - loss: 0.8618 - acc: 0.6204 - val_loss: 0.6482 - val_acc: 0.6944
# Epoch 9/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7725 - acc: 0.6581Epoch 00008: val_acc did not improve
# 18/17 [==============================] - 7s - loss: 0.7783 - acc: 0.6549 - val_loss: 0.5584 - val_acc: 0.7778
# Epoch 10/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7653 - acc: 0.6838Epoch 00009: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7779 - acc: 0.6644 - val_loss: 0.6027 - val_acc: 0.7222
# Epoch 11/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7479 - acc: 0.6912Epoch 00010: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7628 - acc: 0.6861 - val_loss: 3.2594 - val_acc: 0.3056
# Epoch 12/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7356 - acc: 0.6507Epoch 00011: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7327 - acc: 0.6516 - val_loss: 1.1201 - val_acc: 0.5972
# Epoch 13/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6844 - acc: 0.6801Epoch 00012: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7029 - acc: 0.6757 - val_loss: 0.7484 - val_acc: 0.7222
# Epoch 14/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6799 - acc: 0.6985Epoch 00013: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6791 - acc: 0.6931 - val_loss: 0.5759 - val_acc: 0.6944
# Epoch 15/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7586 - acc: 0.7022Epoch 00014: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7612 - acc: 0.7002 - val_loss: 1.1524 - val_acc: 0.5278
# Epoch 16/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7276 - acc: 0.6875
# Epoch 00015: reducing learning rate to 1.9999999494757503e-05.
# Epoch 00015: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7411 - acc: 0.6827 - val_loss: 1.7908 - val_acc: 0.4583
# Epoch 17/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.8307 - acc: 0.6949Epoch 00016: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.8432 - acc: 0.6970 - val_loss: 0.8762 - val_acc: 0.6806
# Epoch 18/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5668 - acc: 0.7390Epoch 00017: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5761 - acc: 0.7313 - val_loss: 0.5314 - val_acc: 0.7917
# Epoch 19/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7232 - acc: 0.6728Epoch 00018: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7106 - acc: 0.6725 - val_loss: 0.4928 - val_acc: 0.7639
# Epoch 20/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6452 - acc: 0.7022Epoch 00019: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6492 - acc: 0.7039 - val_loss: 0.6042 - val_acc: 0.7778
# Epoch 21/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6450 - acc: 0.7390Epoch 00020: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6440 - acc: 0.7424 - val_loss: 0.6150 - val_acc: 0.7500
# Epoch 22/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6474 - acc: 0.7132Epoch 00021: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6465 - acc: 0.7107 - val_loss: 0.4645 - val_acc: 0.7917
# Epoch 23/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6602 - acc: 0.7059Epoch 00022: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6535 - acc: 0.7074 - val_loss: 0.4067 - val_acc: 0.8194
# Epoch 24/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6253 - acc: 0.6949Epoch 00023: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6553 - acc: 0.6822 - val_loss: 0.4345 - val_acc: 0.7917
# Epoch 25/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6628 - acc: 0.7132Epoch 00024: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6739 - acc: 0.7070 - val_loss: 0.4469 - val_acc: 0.8056
# Epoch 26/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6203 - acc: 0.7022
# Epoch 00025: reducing learning rate to 3.999999898951501e-06.
# Epoch 00025: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6220 - acc: 0.7076 - val_loss: 0.4722 - val_acc: 0.7917
# Epoch 27/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5951 - acc: 0.7390Epoch 00026: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6019 - acc: 0.7313 - val_loss: 0.4699 - val_acc: 0.7917
# Epoch 28/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6470 - acc: 0.7132Epoch 00027: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6527 - acc: 0.7107 - val_loss: 0.4879 - val_acc: 0.7917
# Epoch 29/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6781 - acc: 0.7169Epoch 00028: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6728 - acc: 0.7141 - val_loss: 0.4852 - val_acc: 0.8056
# Epoch 30/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6052 - acc: 0.7279Epoch 00029: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6058 - acc: 0.7209 - val_loss: 0.4742 - val_acc: 0.8194
# Epoch 31/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6434 - acc: 0.7022Epoch 00030: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6415 - acc: 0.7113 - val_loss: 0.4848 - val_acc: 0.8056
# Epoch 32/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6030 - acc: 0.7574Epoch 00031: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5988 - acc: 0.7560 - val_loss: 0.4802 - val_acc: 0.8194
# Epoch 33/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6186 - acc: 0.7169Epoch 00032: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6369 - acc: 0.7104 - val_loss: 0.4755 - val_acc: 0.8194
# Epoch 34/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5873 - acc: 0.7463Epoch 00033: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6009 - acc: 0.7382 - val_loss: 0.4534 - val_acc: 0.8194
# Epoch 35/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7536 - acc: 0.6838Epoch 00034: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7431 - acc: 0.6829 - val_loss: 0.4410 - val_acc: 0.8056
# Epoch 36/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5453 - acc: 0.7831
# Epoch 00035: reducing learning rate to 7.999999979801942e-07.
# Epoch 00035: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5411 - acc: 0.7840 - val_loss: 0.4465 - val_acc: 0.8194
# Epoch 37/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5853 - acc: 0.7279Epoch 00036: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5992 - acc: 0.7245 - val_loss: 0.4471 - val_acc: 0.8194
# Epoch 38/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6364 - acc: 0.6985Epoch 00037: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6206 - acc: 0.7078 - val_loss: 0.4472 - val_acc: 0.8194
# Epoch 39/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6247 - acc: 0.7059Epoch 00038: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6194 - acc: 0.7074 - val_loss: 0.4481 - val_acc: 0.8056
# Epoch 40/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6794 - acc: 0.7096Epoch 00039: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6767 - acc: 0.7109 - val_loss: 0.4505 - val_acc: 0.8194
# Epoch 41/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6813 - acc: 0.6912Epoch 00040: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6714 - acc: 0.6898 - val_loss: 0.4496 - val_acc: 0.8333
# Epoch 42/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6292 - acc: 0.6985Epoch 00041: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6281 - acc: 0.7005 - val_loss: 0.4530 - val_acc: 0.8333
# Epoch 43/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6093 - acc: 0.7316Epoch 00042: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6051 - acc: 0.7317 - val_loss: 0.4526 - val_acc: 0.8194
# Epoch 44/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6560 - acc: 0.6691Epoch 00043: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6356 - acc: 0.6838 - val_loss: 0.4524 - val_acc: 0.8194
# Epoch 45/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7075 - acc: 0.7059Epoch 00044: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7030 - acc: 0.7074 - val_loss: 0.4570 - val_acc: 0.8194
# Epoch 46/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6103 - acc: 0.7610
# Epoch 00045: reducing learning rate to 1.600000018697756e-07.
# Epoch 00045: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6424 - acc: 0.7410 - val_loss: 0.4574 - val_acc: 0.8194
# Epoch 47/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7103 - acc: 0.7316Epoch 00046: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7083 - acc: 0.7206 - val_loss: 0.4541 - val_acc: 0.8194
# Epoch 48/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6425 - acc: 0.7279Epoch 00047: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6346 - acc: 0.7356 - val_loss: 0.4493 - val_acc: 0.8194
# Epoch 49/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5219 - acc: 0.7390Epoch 00048: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5466 - acc: 0.7276 - val_loss: 0.4469 - val_acc: 0.8194
# Epoch 50/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6164 - acc: 0.7316Epoch 00049: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6118 - acc: 0.7280 - val_loss: 0.4476 - val_acc: 0.8333
# Epoch 51/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6156 - acc: 0.7537Epoch 00050: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6414 - acc: 0.7525 - val_loss: 0.4483 - val_acc: 0.8333
# Epoch 52/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5837 - acc: 0.7206Epoch 00051: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5904 - acc: 0.7176 - val_loss: 0.4468 - val_acc: 0.8194
# Epoch 53/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5786 - acc: 0.7390Epoch 00052: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5898 - acc: 0.7460 - val_loss: 0.4463 - val_acc: 0.8194
# Epoch 54/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6287 - acc: 0.7316Epoch 00053: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6400 - acc: 0.7243 - val_loss: 0.4498 - val_acc: 0.8194
# Epoch 55/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6533 - acc: 0.7243Epoch 00054: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6392 - acc: 0.7322 - val_loss: 0.4514 - val_acc: 0.8194
# Epoch 56/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5990 - acc: 0.7243
# Epoch 00055: reducing learning rate to 1e-07.
# Epoch 00055: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5944 - acc: 0.7248 - val_loss: 0.4559 - val_acc: 0.8194
# Epoch 57/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5828 - acc: 0.7500Epoch 00056: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6056 - acc: 0.7491 - val_loss: 0.4554 - val_acc: 0.8194
# Epoch 58/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6750 - acc: 0.6949Epoch 00057: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6565 - acc: 0.7044 - val_loss: 0.4575 - val_acc: 0.8194
# Epoch 59/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6760 - acc: 0.7059Epoch 00058: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6604 - acc: 0.7111 - val_loss: 0.4562 - val_acc: 0.8194
# Epoch 60/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6133 - acc: 0.7096Epoch 00059: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6442 - acc: 0.6961 - val_loss: 0.4568 - val_acc: 0.8194
# Epoch 61/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7211 - acc: 0.7096Epoch 00060: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7106 - acc: 0.7146 - val_loss: 0.4585 - val_acc: 0.8194
# Epoch 62/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6504 - acc: 0.6912Epoch 00061: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6286 - acc: 0.7046 - val_loss: 0.4610 - val_acc: 0.8194
# Epoch 63/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6104 - acc: 0.7022Epoch 00062: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6109 - acc: 0.7039 - val_loss: 0.4609 - val_acc: 0.8194
# Epoch 64/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6179 - acc: 0.7059Epoch 00063: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6011 - acc: 0.7148 - val_loss: 0.4670 - val_acc: 0.8194
# Epoch 65/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7122 - acc: 0.6985Epoch 00064: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6987 - acc: 0.7041 - val_loss: 0.4668 - val_acc: 0.8194
# Epoch 66/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7383 - acc: 0.6912Epoch 00065: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.7540 - acc: 0.6898 - val_loss: 0.4685 - val_acc: 0.8194
# Epoch 67/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6030 - acc: 0.7169Epoch 00066: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6083 - acc: 0.7178 - val_loss: 0.4609 - val_acc: 0.8194
# Epoch 68/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6235 - acc: 0.7132Epoch 00067: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6187 - acc: 0.7107 - val_loss: 0.4591 - val_acc: 0.8194
# Epoch 69/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5659 - acc: 0.7463Epoch 00068: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5701 - acc: 0.7382 - val_loss: 0.4579 - val_acc: 0.8194
# Epoch 70/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5989 - acc: 0.7096Epoch 00069: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6085 - acc: 0.7035 - val_loss: 0.4587 - val_acc: 0.8194
# Epoch 71/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6532 - acc: 0.7022Epoch 00070: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6453 - acc: 0.7076 - val_loss: 0.4624 - val_acc: 0.8194
# Epoch 72/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.7094 - acc: 0.6728Epoch 00071: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6990 - acc: 0.6761 - val_loss: 0.4651 - val_acc: 0.8194
# Epoch 73/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6113 - acc: 0.7353Epoch 00072: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6048 - acc: 0.7389 - val_loss: 0.4603 - val_acc: 0.8194
# Epoch 74/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5804 - acc: 0.7353Epoch 00073: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5716 - acc: 0.7389 - val_loss: 0.4574 - val_acc: 0.8194
# Epoch 75/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5544 - acc: 0.7353Epoch 00074: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5486 - acc: 0.7389 - val_loss: 0.4562 - val_acc: 0.8194
# Epoch 76/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6673 - acc: 0.6728Epoch 00075: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6621 - acc: 0.6798 - val_loss: 0.4534 - val_acc: 0.8194
# Epoch 77/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6755 - acc: 0.6875Epoch 00076: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6776 - acc: 0.6900 - val_loss: 0.4543 - val_acc: 0.8194
# Epoch 78/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6363 - acc: 0.6949Epoch 00077: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6404 - acc: 0.6933 - val_loss: 0.4627 - val_acc: 0.8194
# Epoch 79/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6676 - acc: 0.6985Epoch 00078: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6710 - acc: 0.7041 - val_loss: 0.4586 - val_acc: 0.8194
# Epoch 80/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5655 - acc: 0.7206Epoch 00079: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5525 - acc: 0.7250 - val_loss: 0.4656 - val_acc: 0.8194
# Epoch 81/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6421 - acc: 0.7096Epoch 00080: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6348 - acc: 0.7072 - val_loss: 0.4671 - val_acc: 0.8194
# Epoch 82/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5712 - acc: 0.7390Epoch 00081: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5996 - acc: 0.7313 - val_loss: 0.4741 - val_acc: 0.8194
# Epoch 83/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6096 - acc: 0.7059Epoch 00082: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6219 - acc: 0.7037 - val_loss: 0.4746 - val_acc: 0.8194
# Epoch 84/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6210 - acc: 0.7353Epoch 00083: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6120 - acc: 0.7389 - val_loss: 0.4793 - val_acc: 0.8194
# Epoch 85/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6864 - acc: 0.6654Epoch 00084: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6887 - acc: 0.6581 - val_loss: 0.4744 - val_acc: 0.8194
# Epoch 86/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6692 - acc: 0.6912Epoch 00085: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6693 - acc: 0.6898 - val_loss: 0.4755 - val_acc: 0.8194
# Epoch 87/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5619 - acc: 0.7243Epoch 00086: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5628 - acc: 0.7285 - val_loss: 0.4724 - val_acc: 0.8194
# Epoch 88/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6113 - acc: 0.7647Epoch 00087: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6015 - acc: 0.7704 - val_loss: 0.4751 - val_acc: 0.8194
# Epoch 89/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6787 - acc: 0.6985Epoch 00088: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6889 - acc: 0.6931 - val_loss: 0.4719 - val_acc: 0.8194
# Epoch 90/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6785 - acc: 0.7206Epoch 00089: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6704 - acc: 0.7213 - val_loss: 0.4761 - val_acc: 0.8056
# Epoch 91/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6810 - acc: 0.6801Epoch 00090: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6839 - acc: 0.6794 - val_loss: 0.4769 - val_acc: 0.8194
# Epoch 92/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5694 - acc: 0.7463Epoch 00091: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5556 - acc: 0.7567 - val_loss: 0.4732 - val_acc: 0.8194
# Epoch 93/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6082 - acc: 0.7059Epoch 00092: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6074 - acc: 0.7111 - val_loss: 0.4827 - val_acc: 0.8056
# Epoch 94/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5875 - acc: 0.7243Epoch 00093: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5795 - acc: 0.7248 - val_loss: 0.4856 - val_acc: 0.8056
# Epoch 95/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5821 - acc: 0.7316Epoch 00094: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5975 - acc: 0.7243 - val_loss: 0.4798 - val_acc: 0.8194
# Epoch 96/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6214 - acc: 0.7353Epoch 00095: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6310 - acc: 0.7315 - val_loss: 0.4800 - val_acc: 0.8194
# Epoch 97/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6100 - acc: 0.6985Epoch 00096: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6063 - acc: 0.6968 - val_loss: 0.4841 - val_acc: 0.8194
# Epoch 98/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5922 - acc: 0.7243Epoch 00097: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6040 - acc: 0.7211 - val_loss: 0.4850 - val_acc: 0.8194
# Epoch 99/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.6288 - acc: 0.6949Epoch 00098: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.6353 - acc: 0.6970 - val_loss: 0.4852 - val_acc: 0.8194
# Epoch 100/100
# 17/17 [===========================>..] - ETA: 0s - loss: 0.5551 - acc: 0.7426Epoch 00099: val_acc did not improve
# 18/17 [==============================] - 5s - loss: 0.5403 - acc: 0.7532 - val_loss: 0.4776 - val_acc: 0.8194

# %%
with open('history.json', 'w') as f:
    json.dump(str(history.history), f)

# %%
history_df = pd.DataFrame(history.history)
history_df[['acc', 'val_acc']].plot()
# Out:
# <AxesSubplot:>

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
model.load_weights("huaxi_Inception_bydai_weights.best.hdf5")

# %%
Y_val_pred = model.predict(x_val)

# %%
from sklearn.metrics import classification_report
print(classification_report(np.argmax(y_val, axis=1),np.argmax(Y_val_pred, axis=1),target_names=['benign','mallignant']))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.95      0.88      0.91        59
#   mallignant       0.59      0.77      0.67        13
#
#     accuracy                           0.86        72
#    macro avg       0.77      0.83      0.79        72
# weighted avg       0.88      0.86      0.87        72

# %%
accuracy_score(np.argmax(y_val, axis=1), np.argmax(Y_val_pred, axis=1))
# Out:
# 0.8611111111111112

# %%
Y_pred = model.predict(X_test)

# %%
tta_steps = 10
predictions = []

for i in tqdm(range(tta_steps)):
    preds = model.predict_generator(train_generator.flow(X_test, batch_size=BATCH_SIZE, shuffle=False),
                                    steps = len(X_test)/BATCH_SIZE)
    
    predictions.append(preds)
    gc.collect()
    
Y_pred_tta = np.mean(predictions, axis=0) # 计算每一列的均值
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:09<00:00,  1.06it/s]

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test1, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[66 23]
#  [12 19]]

# %%
cm = confusion_matrix(np.argmax(Y_test1, axis=1), np.argmax(Y_pred_tta, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[84  5]
#  [20 11]]

# %%
from sklearn.metrics import classification_report
#classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
print(classification_report(np.argmax(Y_test1, axis=1),np.argmax(Y_pred, axis=1),target_names=['benign','mallignant']))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.85      0.74      0.79        89
#   mallignant       0.45      0.61      0.52        31
#
#     accuracy                           0.71       120
#    macro avg       0.65      0.68      0.66       120
# weighted avg       0.74      0.71      0.72       120

# %%
from sklearn.metrics import classification_report
#classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
print(classification_report(np.argmax(Y_test1, axis=1),np.argmax(Y_pred_tta, axis=1),target_names=['benign','mallignant']))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.81      0.94      0.87        89
#   mallignant       0.69      0.35      0.47        31
#
#     accuracy                           0.79       120
#    macro avg       0.75      0.65      0.67       120
# weighted avg       0.78      0.79      0.77       120

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test1, axis=1), np.argmax(Y_pred, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test1, axis=1), np.argmax(Y_pred, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(Y_test1)):
    if(np.argmax(Y_test1[i])==np.argmax(Y_pred_tta[i])):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(Y_test1)):
    if(not np.argmax(Y_test1[i])==np.argmax(Y_pred_tta[i])):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# # Display first 8 images of benign
w=60
h=40
fig=plt.figure(figsize=(18, 10))
columns = 4
rows = 2

def Transfername(namecode):
    if namecode==0:
        return "Benign"
    else:
        return "Malignant"
    
for i in range(len(prop_class)):
    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title("Predicted result:"+ Transfername(np.argmax(Y_pred_tta[prop_class[i]]))
                       +"\n"+"Actual result: "+ Transfername(np.argmax(Y_test[prop_class[i]])))
    plt.imshow(X_test[prop_class[i]], interpolation='nearest')
plt.show()

# %%
layer_name = 'batch_normalization_95'
FC_layer_model = Model(inputs=model.input,
                                 outputs=model.get_layer(layer_name).output)

# %%
import glob
import cv2
import os
#Find the Features for n number of train images and we will get n x 2048
#This means we will get 2048 features for each images.

patth =  'C:/Users/user/Desktop/github/train'


j=0
features=np.zeros(shape=(X_train.shape[0],2048))
folders = list(filter(lambda x: os.path.isdir(os.path.join(patth, x)), os.listdir(patth)))
for i in folders:
  img_patth = os.path.join(patth,i)
  for img_path in glob.glob(img_patth + '/*.png'):
    img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
    img = cv2.resize(img, (224, 224))
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    img = np.expand_dims(img,axis=0)
    FC_output = FC_layer_model.predict(img)
    features[j]=FC_output
    j+=1

# %%
features.shape
# Out:
# (359, 2048)

# %%
np.save('features', features)

# %%
#Name the feature rows as f_0, f_1, f_2...
feature_col=[]
for i in range(2048):
    feature_col.append("f_"+str(i))
    i+=1

# %%
#Create DataFrame with features and coloumn name

import pandas as pd 
train_features=pd.DataFrame(data=features,columns=feature_col)
feature_col = np.array(feature_col)

train_class = list(np.unique(Y_train))
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', Y_train.shape)
# Out:
# Training Features Shape: (359, 2048)
# Training Labels Shape: (359,)

# %%
train_features
# Out:
#           f_0       f_1       f_2       f_3       f_4       f_5       f_6  \
# 0    0.387908  0.171459  0.289263 -0.034055 -0.038379 -0.022224 -0.219344
# 1   -0.115962 -0.154164 -0.017040  0.544326  0.842670 -0.144510  0.333108
# 2   -0.206521 -0.105513 -0.067822  0.489098  0.146607 -0.201670 -0.200831
# 3   -0.154905 -0.134726 -0.074336  0.045003  0.505643  0.460312  1.417531
# 4   -0.258817 -0.178533 -0.143460  0.180747  0.288567 -0.140979 -0.258642
# ..        ...       ...       ...       ...       ...       ...       ...
# 354 -0.134454  0.264915  1.063839  1.090906  0.223572  0.102185  0.003465
# 355 -0.051625 -0.043710  0.041008  0.000189  0.048101 -0.210863  0.461923
# 356 -0.136772 -0.164258  0.215573  0.124079 -0.051013  0.072900  0.039425
# 357 -0.195147  0.184720  0.249362  0.237156  1.009928 -0.200425 -0.172559
# 358 -0.135310 -0.140604 -0.165498 -0.065189  0.750650  0.110154 -0.243940
#
#           f_7       f_8       f_9  ...    f_2038    f_2039    f_2040  \
# 0   -0.169548 -0.169029 -0.005162  ...  0.446232  0.139098 -0.204943
# 1    0.401562 -0.075693 -0.106669  ...  0.619773 -0.115454  0.334746
# 2   -0.236537 -0.041794  0.057021  ...  0.850645 -0.260809 -0.029885
# 3   -0.146777 -0.253534 -0.046434  ...  1.995158  0.824969 -0.240329
# 4   -0.156917 -0.086031 -0.179287  ... -0.186556 -0.310192 -0.283884
# ..        ...       ...       ...  ...       ...       ...       ...
# 354  0.321219  0.162761 -0.282118  ... -0.309373  0.549604  0.095596
# 355 -0.281606 -0.237793 -0.281094  ... -0.306087 -0.166252 -0.283884
# 356  0.185168  0.060695 -0.100236  ...  0.137850  0.088583  0.243662
# 357 -0.156050  0.524886 -0.260901  ...  1.201155 -0.233429 -0.282484
# 358  0.038838 -0.085587  0.024752  ...  0.558191 -0.228238 -0.103624
#
#        f_2041    f_2042    f_2043    f_2044    f_2045    f_2046    f_2047
# 0    0.492198  1.036852 -0.109203  0.587424 -0.338440  0.644142 -0.223161
# 1    0.796202 -0.266413  3.409781 -0.160854  1.782856 -0.186281  0.431995
# 2    1.116012 -0.037656  0.249153 -0.184516  1.297295 -0.321437 -0.078113
# 3    1.441732  0.096843 -0.079678  1.804675  0.325016  0.290216  0.007972
# 4    2.850459  0.338978  0.585356  0.158897  1.851362 -0.262370 -0.023832
# ..        ...       ...       ...       ...       ...       ...       ...
# 354  0.263008  1.107048  2.431311  0.507685  0.749060  0.815315  0.466413
# 355  1.382550  0.429901  0.110525 -0.189653  0.427575 -0.321437 -0.301094
# 356  0.274288  0.937585  1.302505  0.063613  1.477788  1.871593  0.273162
# 357 -0.238283  0.797503  0.603314  1.047836 -0.030899  1.054258 -0.301094
# 358  1.773658  0.173576  0.262645 -0.184569  1.235797  1.068390  0.434847
#
# [359 rows x 2048 columns]

# %%
np.savetxt("bydai.csv", train_features, delimiter=',')

# %%
import glob
import cv2
import os
#Find the Features for n number of train images and we will get n x 2048
#This means we will get 2048 features for each images.

patth =  'C:/Users/user/Desktop/github/validation'

k=0
features_test=np.zeros(shape=(Y_test.shape[0],2048))
folders = list(filter(lambda x: os.path.isdir(os.path.join(patth, x)), os.listdir(patth)))
for i in folders:
  img_patth = os.path.join(patth,i)
  for img_path in glob.glob(img_patth + '/*.png'):
    img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
    img = cv2.resize(img, (224, 224))
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    img = np.expand_dims(img,axis=0)
    FC_output = FC_layer_model.predict(img)
    features_test[k]=FC_output
    k+=1

# %%
np.save('features_test',features_test)

# %%
#Create DataFrame with features and coloumn name
import pandas as pd
test_features=pd.DataFrame(data=features_test,columns=feature_col)
feature_col = np.array(feature_col)

print('Test Features Shape:', test_features.shape)
print('Test Labels Shape:', Y_test.shape)
# Out:
# Test Features Shape: (120, 2048)
# Test Labels Shape: (120,)

# %%
test_features
# Out:
#           f_0       f_1       f_2       f_3       f_4       f_5       f_6  \
# 0    0.090835 -0.265560  0.316293  0.169924  0.017390  0.042987 -0.090557
# 1   -0.258817 -0.086404 -0.234518  0.079703  0.244413  0.049072  0.442797
# 2   -0.080687 -0.174182 -0.242336 -0.229827  0.179210  0.801209  0.167813
# 3   -0.241458 -0.025703 -0.237958  0.030760  0.055888  0.086967  0.493442
# 4   -0.158855 -0.096412  0.169468 -0.143643  0.791317  0.006478 -0.175759
# ..        ...       ...       ...       ...       ...       ...       ...
# 115  0.213032  0.017321  0.378854 -0.287817  0.015625 -0.025210 -0.093888
# 116 -0.217829 -0.195670 -0.121334  0.040230  0.556683  0.445277 -0.162372
# 117 -0.018754 -0.190864 -0.002620  0.035584  0.240972  0.267048  0.481421
# 118  0.497094  0.204512  0.824527 -0.002435  0.222208  0.048890 -0.172212
# 119 -0.196918 -0.009861 -0.015380  0.115560  0.351979 -0.113128  0.288385
#
#           f_7       f_8       f_9  ...    f_2038    f_2039    f_2040  \
# 0    0.074134 -0.159551 -0.058181  ...  0.442054 -0.302621 -0.283884
# 1   -0.274710  0.177678 -0.209188  ... -0.208790  0.694565 -0.223572
# 2   -0.169297  0.970594 -0.243750  ...  0.282216  1.038418  0.486575
# 3   -0.081601  0.083923 -0.290707  ... -0.250984 -0.145569 -0.283884
# 4    0.406506 -0.259105 -0.274816  ...  0.441042 -0.292449 -0.283884
# ..        ...       ...       ...  ...       ...       ...       ...
# 115 -0.257358  0.033848 -0.133331  ...  0.497203  1.473745  0.403255
# 116  0.068588  0.034223  0.520244  ...  0.849627 -0.312505 -0.159354
# 117 -0.134843  0.046995 -0.288898  ...  1.611591  0.541162 -0.262185
# 118 -0.242924 -0.311142 -0.273111  ... -0.309373  1.328229 -0.146241
# 119  0.020022 -0.312862 -0.288151  ...  0.769380  0.302327 -0.010687
#
#        f_2041    f_2042    f_2043    f_2044    f_2045    f_2046    f_2047
# 0    0.807394  1.466791  0.836134  0.397027 -0.002965  0.878254 -0.292717
# 1    1.902749  0.910799  0.081064 -0.247262  0.356443 -0.239729 -0.300169
# 2    1.907247  1.968057  1.635967  0.006955 -0.266251 -0.243914 -0.299020
# 3    0.170404 -0.084885  0.874955  0.205348  0.096533 -0.065284 -0.057488
# 4    0.377543 -0.069956  1.247158  0.427817 -0.296139  0.236316 -0.129761
# ..        ...       ...       ...       ...       ...       ...       ...
# 115  1.307947  1.077903  0.685814 -0.246318  1.634833  0.375528  0.120370
# 116  0.724660 -0.065295  2.417072 -0.140196  1.597713  1.387689  0.929260
# 117  0.209602  1.508282  0.320941  0.212645  1.188028  0.760405 -0.005436
# 118  1.375836  0.330331  0.198930  0.911622 -0.123728  0.427732 -0.246282
# 119  0.446464  1.375603  1.412901 -0.051609  2.340114  0.485086  1.407022
#
# [120 rows x 2048 columns]

# %%
np.savetxt("bydai_test.csv", test_features, delimiter=',')
